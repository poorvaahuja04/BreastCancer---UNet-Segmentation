# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (2).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (285).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (166)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (290)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (300).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (390).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (357).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (430)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (89)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (261)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (428).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (233)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (98).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (295)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (52)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (246).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (15)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (217).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (276).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (103).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (342).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (181).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (71).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (50).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (13)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (265).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (352)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (383)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (84)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (6).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (160).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (147).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (227)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (308).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (294).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (403)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (171)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (53)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (208)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (304).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (404).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (173)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (43)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (108).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (284).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (381).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (329).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (363)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (179).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (47).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (289).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (264).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (369).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (131).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (224).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (163).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (26).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (163)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (134)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (331)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (153)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (79)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (235)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (225).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (74)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (405)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (371)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (54).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (133)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (221).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (249).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (184).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (380).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (96)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (232).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (143)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (185).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (211).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (187).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (337)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (368).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (278)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (46).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (120).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (99)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (429).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (266).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (329)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (260)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (410)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (346).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (62)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (104).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (406).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (331).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (22)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (360).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (7).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (302).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (70)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (26)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (167)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (128)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (344)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (314)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (426).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (369)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (206).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (170)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (70).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (345).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (102)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (127).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (302)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (166).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (266)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (145)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (92)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (253).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (370)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (177)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (63).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (349)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (85).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (158)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (420).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (126).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (151)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (401).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (312)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (432)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (339)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (4)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (262).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (254)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (3).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (56).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (64)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (195)_mask_2.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (437).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (207)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (126)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (316).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (121)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (83)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (170).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (82)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (12)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (374).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (174)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (397)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (340).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (420)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (12).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (417)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (335).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (18).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (377)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (226)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (123)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (409)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (215)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (181)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (356)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (61).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (145).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (66)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (218).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (298).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (195)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (48)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (374)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (205)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (380)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (299)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (169)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (411)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (152)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (212)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (44).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (365).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (203).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (110).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (88)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (250)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (137).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (261).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (419).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (307)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (356).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (101)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (375).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (50)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (75)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (114)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (193).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (365)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (16).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (5)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (195)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (410).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (299).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (320)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (336).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (392).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (199)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (189).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (5).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (254).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (407).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (321)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (322).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (395).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (173).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (103)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (270)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (401)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (333).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (416).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (306).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (422).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (105)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (402).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (182)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (346)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (132).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (354).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (4)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (310).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (201)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (25)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (165).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (32)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (288).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (58)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (257)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (324).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (24)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (413)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (345)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (282)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (292).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (404)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (11).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (388)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (175)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (25).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (52).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (37)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (196).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (376)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (396).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (148).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (187)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (231)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (183)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (19).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (315).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (340)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (284)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (18)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (237)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (183).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (57)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (306)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (334)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (292)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (38)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (94)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (384)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (138).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (141).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (285)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (109)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (222)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (67)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (271).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (169).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (73)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (371).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (243)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (378).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (236)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (362)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (209)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (307).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (87)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (407)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (373)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (214)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (35)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (326).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (97)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (274)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (65).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (422)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (54)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (263)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (347)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (235).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (252).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (139).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (74).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (40).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (259)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (250).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (390)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (40)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (149)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (153).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (367)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (186)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (180).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (75).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (239)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (429)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (53).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (432).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (194).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (2)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (214).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (171).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (370).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (81)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (144).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (79).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (427).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (402)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (146).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (366).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (238)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (313)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (419)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (405).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (204).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (323)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (144)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (314).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (51).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (122)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (173)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (172)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (217)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (197)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (320).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (385)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (129)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (399)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (353).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (400).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (274).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (421)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (378)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (59)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (385).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (45).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (38).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (140)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (205).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (34).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (247).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (8)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (415).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (161).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (87).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (257).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (291).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (78).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (19)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (259).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (350).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (140).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (10).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (222).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (319)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (188)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (136).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (291)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (317).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (239).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (240).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (295).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (4).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (93)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (398).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (321).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (11)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (83).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (31)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (115).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (269)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (387)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (219).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (152).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (71)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (338)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (260).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (94).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (65)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (48).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (346)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (258)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (206)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (221)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (351).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (68)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (406)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (83)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (128).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (386)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (229).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (7)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (399).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (236).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (186).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (237).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (14)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (199).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (325).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (379).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (231).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (398)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (123).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (272)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (189)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (391)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (16)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (69)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (394).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (177).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (343)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (8).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (124).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (305)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (97).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (248).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (359)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (308)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (96).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (167).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (353)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (282).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (143).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (255)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (111).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (32).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (315)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (269).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (381)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (164)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (256)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (204)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (241).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (6)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (213).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (296).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (240)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (424)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (149).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (337).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (82).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (393)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (256).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (434).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (198)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (42)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (433)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (55)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (181)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (92)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (202).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (160)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (242)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (115)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (39).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (265)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (28)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (326)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (21)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (78)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (112).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (309).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (244).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (28).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (134).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (100)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (437)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (106).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (155)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (176).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (396)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (110)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (80).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (58)_mask_1.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (45)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (34)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (279).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (49).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (362).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (182).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (165)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (44)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (318).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (278).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (112)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/benign/benign (80)_mask.png
# ...
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (173).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (83)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (13).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (186)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (141).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (52).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (59)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (112)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (202).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (33)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (120)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (122)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (119)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (100)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (207).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (142).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (201).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (11).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (56)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (147)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (127).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (35).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (44)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (55).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (206).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (152)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (12)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (73)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (33).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (99).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (179).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (36)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (129)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (185)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (71)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (26)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (90)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (31)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (183)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (85)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (148).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (93).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (61).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (205).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (143)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (181).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (43)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (114).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (111).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (154)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (134)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (175).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (133)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (78)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (187)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (209)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (58)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (57)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (115)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (155)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (25).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (47)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (51).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (72).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (46)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (136)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (204).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (169)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (119).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (108).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (48).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (61)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (14).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (69)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (37)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (89)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (130).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (194).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (169).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (67)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (122).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (60).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (135).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (115).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (110).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (192)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (24).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (109)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (132)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (88)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (45)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (12).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (62).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (170)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (64).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (135)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (193)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (94).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (178)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (22).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (177).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (190).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (146).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (157).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (142)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (194)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (57).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (86)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (208)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (1)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (27).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (98)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (69).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (185).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (24)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (113).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (9).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (137)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (166).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (131)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (4).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (18).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (146)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (96)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (22)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (138)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (42)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (49)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (104).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (20)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (126).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (157)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (181)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (130)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (50)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (165).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (186).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (137).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (100).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (180)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (196)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (2).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (105).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (171)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (124).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (107)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (200)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (6)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (8)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (149)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (95)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (150)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (156)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (133).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (6).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (193).png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (74)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (75)_mask.png
# /kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/malignant/malignant (184).png

# %%
import tensorflow as tf
from glob import glob
import numpy as np
from sklearn.model_selection import train_test_split
import cv2
# Out:
# 2025-08-25 11:38:34.860153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756121915.060483      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756121915.121705      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from keras.optimizers import Adam
from tensorflow.keras.metrics import *

# %%
def load_image(path, size):
    image = cv2.imread(path)
    image = cv2.resize(image, (size,size))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)   # shape: (size,size,3) -> (size,size,1)
    image = image/255.   # normalize
    return image

# %%
def load_data(root_path, size):
    images = []
    masks = []
    x = 0
    for path in sorted(glob(root_path)):
        img = load_image(path, size)
        if 'mask' in path:
            if x:
                masks[-1] += img
                masks[-1] = np.array(masks[-1] > 0, dtype='float64')
            else:
                masks.append(img)
                x=1
        else:
            images.append(img)
            x = 0
    return np.array(images), np.array(masks)

# %%
X, y = load_data(root_path = '/kaggle/input/breast-ultrasound-images-dataset/Dataset_BUSI_with_GT/*/*', size=128)

# %%
X.shape
# Out:
# (780, 128, 128)

# %% [markdown]
# # EDA

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 5))
# X[0:437] benign
# X[437:647] malignant
# X[647:780] normal
i = np.random.randint(647, 780)
ax[0].imshow(X[i], cmap = 'gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Normal class', fontsize=16)
plt.show()
# Out:
# I0000 00:00:1756121945.815993      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1756121945.816680      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

i = np.random.randint(437)
ax[0].imshow(X[i], cmap='gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Benign class', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

i = np.random.randint(437,647)
ax[0].imshow(X[i], cmap='gray')
ax[0].set_title('Image')
ax[1].imshow(y[i], cmap='gray')
ax[1].set_title('Mask')
ax[2].imshow(X[i], cmap='gray')
ax[2].imshow(tf.squeeze(y[i]), alpha=0.5, cmap='jet')
ax[2].set_title('Union')
fig.suptitle('Malignant class', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(10,5))

ax[0].imshow(sum(y[647:]), cmap='gray')
ax[0].set_title('Normal')
ax[1].imshow(sum(y[:437]), cmap='gray')
ax[1].set_title('Benign')
ax[2].imshow(sum(y[437:647]), cmap='gray')
ax[2].set_title('Malignant')
plt.show()

# %%
X = X[:647]
y = y[:647]
print(f"X shape: {X.shape}    | y shape: {y.shape}")
X = np.expand_dims(X, -1)
y = np.expand_dims(y, -1)
print(f"\nX shape: {X.shape} | y shape: {y.shape}")
# Out:
# X shape: (647, 128, 128)    | y shape: (647, 128, 128)
#
# X shape: (647, 128, 128, 1) | y shape: (647, 128, 128, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

print(f'\033[92m')
print('X_train shape:',X_train.shape)
print('y_train shape:',y_train.shape)
print('X_test shape:',X_test.shape)
print('y_test shape:',y_test.shape)
# Out:
# X_train shape: (582, 128, 128, 1)
# y_train shape: (582, 128, 128, 1)
# X_test shape: (65, 128, 128, 1)
# y_test shape: (65, 128, 128, 1)

# %% [markdown]
# # UNet Architecture

# %%
def conv_block(input, num_filters):
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(input)
    conv = Conv2D(num_filters, (3, 3), activation="relu", padding="same", kernel_initializer='he_normal')(conv)
    return conv

# %%
def encoder_block(input, num_filters):
    conv = conv_block(input, num_filters)
    pool = MaxPooling2D((2, 2))(conv)
    return conv, pool

# %%
def decoder_block(input, skip_features, num_filters):
    uconv = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    con = concatenate([uconv, skip_features])
    conv = conv_block(con, num_filters)
    return conv

# %%
size = 128
def build_model(input_shape):
    input_layer = Input(input_shape)
    s1, p1 = encoder_block(input_layer, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    output_layer = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = Model(input_layer, output_layer, name="U-Net")
    return model

model = build_model(input_shape=(size, size, 1))
model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ conv2d_8[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  2,097,664 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │    524,544 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    131,200 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │     32,832 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_16[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         65 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,030,593 (118.37 MB)
#  Trainable params: 31,030,593 (118.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.2.1)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->visualkeras) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
import visualkeras
from PIL import ImageFont
import matplotlib.pyplot as plt

# Optional font
font = ImageFont.load_default()

# Save model diagram to file
img = visualkeras.layered_view(model, legend=True, font=font, to_file="model.png")

# Display inline in Kaggle notebook
plt.imshow(plt.imread("model.png"))
plt.axis("off")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756121962.791973      65 service.cc:148] XLA service 0x7974d000b450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1756121962.792796      65 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1756121962.792815      65 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1756121963.748125      65 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1756122009.877038      65 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 18/19 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.7709 - loss: 0.4357
# E0000 00:00:1756122026.613189      63 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1756122026.846981      63 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - accuracy: 0.7778 - loss: 0.4343 - val_accuracy: 0.8947 - val_loss: 0.3770
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 508ms/step - accuracy: 0.9051 - loss: 0.3315 - val_accuracy: 0.8947 - val_loss: 0.3327
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 489ms/step - accuracy: 0.9089 - loss: 0.3005 - val_accuracy: 0.8947 - val_loss: 0.3376
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 473ms/step - accuracy: 0.9063 - loss: 0.2920 - val_accuracy: 0.8954 - val_loss: 0.2984
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 464ms/step - accuracy: 0.9120 - loss: 0.2517 - val_accuracy: 0.8947 - val_loss: 0.2733
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 461ms/step - accuracy: 0.9082 - loss: 0.2579 - val_accuracy: 0.8947 - val_loss: 0.2822
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 461ms/step - accuracy: 0.9138 - loss: 0.2229 - val_accuracy: 0.8066 - val_loss: 0.4527
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 466ms/step - accuracy: 0.8868 - loss: 0.3234 - val_accuracy: 0.8947 - val_loss: 0.2641
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 469ms/step - accuracy: 0.9048 - loss: 0.2345 - val_accuracy: 0.8947 - val_loss: 0.2348
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 475ms/step - accuracy: 0.9059 - loss: 0.2132 - val_accuracy: 0.8982 - val_loss: 0.2071

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,3))
ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax[0].legend()
ax[1].plot(history.epoch, history.history["accuracy"], label="Train accuracy")
ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation accuracy")
ax[1].legend()
fig.suptitle('Loss and Accuracy', fontsize=16)
plt.show()

# %% [markdown]
# # Evaluation

# %%
fig, ax = plt.subplots(5, 3, figsize=(10, 18))
j = np.random.randint(0, X_test.shape[0], 5)
for i in range(5):
    ax[i,0].imshow(X_test[j[i]], cmap='gray')
    ax[i,0].set_title('Image')
    ax[i,1].imshow(y_test[j[i]], cmap='gray')
    ax[i,1].set_title('Mask')
    ax[i,2].imshow(model.predict(np.expand_dims(X_test[j[i]],0),verbose=0)[0], cmap='gray')
    ax[i,2].set_title('Prediction')
fig.suptitle('Results', fontsize=16)
plt.show()
